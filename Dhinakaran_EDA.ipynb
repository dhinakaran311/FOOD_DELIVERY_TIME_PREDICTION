# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Food_Delivery_Times.csv")
df
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         522         7.93   Windy           Low   Afternoon      Scooter
# 1         738        16.42   Clear        Medium     Evening         Bike
# 2         741         9.52   Foggy           Low       Night      Scooter
# 3         661         7.44   Rainy        Medium   Afternoon      Scooter
# 4         412        19.03   Clear           Low     Morning         Bike
# ..        ...          ...     ...           ...         ...          ...
# 995       107         8.50   Clear          High     Evening          Car
# 996       271        16.28   Rainy           Low     Morning      Scooter
# 997       861        15.62   Snowy          High     Evening      Scooter
# 998       436        14.17   Clear           Low   Afternoon         Bike
# 999       103         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# ...

# %%
df.head()
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
df.tail()
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 995       107         8.50   Clear          High     Evening          Car
# 996       271        16.28   Rainy           Low     Morning      Scooter
# 997       861        15.62   Snowy          High     Evening      Scooter
# 998       436        14.17   Clear           Low   Afternoon         Bike
# 999       103         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 995                    13                     3.0                 54
# 996                     8                     9.0                 71
# 997                    26                     2.0                 81
# 998                     8                     0.0                 55
# 999                    24                     3.0                 58

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Distance_km                0
# Weather                   30
# Traffic_Level             30
# Time_of_Day               30
# Vehicle_Type               0
# Preparation_Time_min       0
# Courier_Experience_yrs    30
# Delivery_Time_min          0
# dtype: int64

# %%
df_cleaned=df.dropna()
df_cleaned
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         522         7.93   Windy           Low   Afternoon      Scooter
# 1         738        16.42   Clear        Medium     Evening         Bike
# 2         741         9.52   Foggy           Low       Night      Scooter
# 3         661         7.44   Rainy        Medium   Afternoon      Scooter
# 4         412        19.03   Clear           Low     Morning         Bike
# ..        ...          ...     ...           ...         ...          ...
# 995       107         8.50   Clear          High     Evening          Car
# 996       271        16.28   Rainy           Low     Morning      Scooter
# 997       861        15.62   Snowy          High     Evening      Scooter
# 998       436        14.17   Clear           Low   Afternoon         Bike
# 999       103         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# Order_ID                  0
# Distance_km               0
# Weather                   0
# Traffic_Level             0
# Time_of_Day               0
# Vehicle_Type              0
# Preparation_Time_min      0
# Courier_Experience_yrs    0
# Delivery_Time_min         0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 883 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                883 non-null    int64
#  1   Distance_km             883 non-null    float64
#  2   Weather                 883 non-null    object
#  3   Traffic_Level           883 non-null    object
#  4   Time_of_Day             883 non-null    object
#  5   Vehicle_Type            883 non-null    object
#  6   Preparation_Time_min    883 non-null    int64
#  7   Courier_Experience_yrs  883 non-null    float64
#  8   Delivery_Time_min       883 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 69.0+ KB

# %%
df_cleaned.describe()
# Out:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   883.000000   883.000000            883.000000              883.000000
# mean    508.109853    10.051586             17.019253                4.639864
# std     287.925161     5.688582              7.260201                2.922172
# min       1.000000     0.590000              5.000000                0.000000
# 25%     263.500000     5.130000             11.000000                2.000000
# 50%     512.000000    10.280000             17.000000                5.000000
# 75%     758.500000    15.025000             23.000000                7.000000
# max    1000.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count         883.000000
# mean           56.425821
# std            21.568482
# min             8.000000
# 25%            41.000000
# 50%            55.000000
# 75%            71.000000
# max           141.000000

# %%
df_cleaned.shape
# Out:
# (883, 9)

# %%
df_cleaned.head()
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
df_cleaned.tail()
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 995       107         8.50   Clear          High     Evening          Car
# 996       271        16.28   Rainy           Low     Morning      Scooter
# 997       861        15.62   Snowy          High     Evening      Scooter
# 998       436        14.17   Clear           Low   Afternoon         Bike
# 999       103         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 995                    13                     3.0                 54
# 996                     8                     9.0                 71
# 997                    26                     2.0                 81
# 998                     8                     0.0                 55
# 999                    24                     3.0                 58

# %%
df_cleaned.drop(labels=['Order_ID'],axis=1)
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0           7.93   Windy           Low   Afternoon      Scooter
# 1          16.42   Clear        Medium     Evening         Bike
# 2           9.52   Foggy           Low       Night      Scooter
# 3           7.44   Rainy        Medium   Afternoon      Scooter
# 4          19.03   Clear           Low     Morning         Bike
# ..           ...     ...           ...         ...          ...
# 995         8.50   Clear          High     Evening          Car
# 996        16.28   Rainy           Low     Morning      Scooter
# 997        15.62   Snowy          High     Evening      Scooter
# 998        14.17   Clear           Low   Afternoon         Bike
# 999         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                      12                     1.0                 43
# ...

# %%
df_cleaned.duplicated().sum()
# Out:
# 0

# %%
df_cleaned.columns
# Out:
# Index(['Order_ID', 'Distance_km', 'Weather', 'Traffic_Level', 'Time_of_Day',
#        'Vehicle_Type', 'Preparation_Time_min', 'Courier_Experience_yrs',
#        'Delivery_Time_min'],
#       dtype='object')

# %%
df_cleaned.dtypes
# Out:
# Order_ID                    int64
# Distance_km               float64
# Weather                    object
# Traffic_Level              object
# Time_of_Day                object
# Vehicle_Type               object
# Preparation_Time_min        int64
# Courier_Experience_yrs    float64
# Delivery_Time_min           int64
# dtype: object

# %%
category=df_cleaned[['Weather','Traffic_Level','Time_of_Day','Vehicle_Type']]

# %%
category.describe()
# Out:
#        Weather Traffic_Level Time_of_Day Vehicle_Type
# count      883           883         883          883
# unique       5             3           4            3
# top      Clear        Medium     Morning         Bike
# freq       425           355         281          451

# %%
df_cleaned['Weather'].unique()
# Out:
# array(['Windy', 'Clear', 'Foggy', 'Rainy', 'Snowy'], dtype=object)

# %%
df_cleaned['Weather'].value_counts()
# Out:
# Weather
# Clear    425
# Rainy    188
# Foggy     98
# Windy     86
# Snowy     86
# Name: count, dtype: int64

# %%
df_cleaned['Traffic_Level'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
df_cleaned['Traffic_Level'].value_counts()
# Out:
# Traffic_Level
# Medium    355
# Low       347
# High      181
# Name: count, dtype: int64

# %%
df_cleaned['Time_of_Day'].unique()
# Out:
# array(['Afternoon', 'Evening', 'Night', 'Morning'], dtype=object)

# %%
df_cleaned['Time_of_Day'].value_counts()
# Out:
# Time_of_Day
# Morning      281
# Evening      269
# Afternoon    257
# Night         76
# Name: count, dtype: int64

# %%
df_cleaned['Vehicle_Type'].unique()
# Out:
# array(['Scooter', 'Bike', 'Car'], dtype=object)

# %%
df_cleaned['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Bike       451
# Scooter    260
# Car        172
# Name: count, dtype: int64

# %%
numerical_columns=df_cleaned.select_dtypes(exclude='object').columns
categorical_columns=df_cleaned.select_dtypes(include='object').columns

# %%
numerical_columns
# Out:
# Index(['Order_ID', 'Distance_km', 'Preparation_Time_min',
#        'Courier_Experience_yrs', 'Delivery_Time_min'],
#       dtype='object')

# %%
categorical_columns
# Out:
# Index(['Weather', 'Traffic_Level', 'Time_of_Day', 'Vehicle_Type'], dtype='object')

# %%
df_cleaned[numerical_columns]
# Out:
#      Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# 0         522         7.93                    12                     1.0
# 1         738        16.42                    20                     2.0
# 2         741         9.52                    28                     1.0
# 3         661         7.44                     5                     1.0
# 4         412        19.03                    16                     5.0
# ..        ...          ...                   ...                     ...
# 995       107         8.50                    13                     3.0
# 996       271        16.28                     8                     9.0
# 997       861        15.62                    26                     2.0
# 998       436        14.17                     8                     0.0
# 999       103         6.63                    24                     3.0
#
#      Delivery_Time_min
# 0                   43
# 1                   84
# ...

# %%
df_cleaned[categorical_columns]
# Out:
#     Weather Traffic_Level Time_of_Day Vehicle_Type
# 0     Windy           Low   Afternoon      Scooter
# 1     Clear        Medium     Evening         Bike
# 2     Foggy           Low       Night      Scooter
# 3     Rainy        Medium   Afternoon      Scooter
# 4     Clear           Low     Morning         Bike
# ..      ...           ...         ...          ...
# 995   Clear          High     Evening          Car
# 996   Rainy           Low     Morning      Scooter
# 997   Snowy          High     Evening      Scooter
# 998   Clear           Low   Afternoon         Bike
# 999   Foggy           Low       Night      Scooter
#
# [883 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in numerical_columns:
    sns.histplot(data=df_cleaned,x=i,kde=True)
    print('\n')
    plt.show()

# %%
x=1
for i in categorical_columns:
    sns.countplot(data=df_cleaned,x=i)
    print('\n')
    plt.show()

# %%
numeric_df = df_cleaned.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(df_cleaned)

# %%
clear=df_cleaned[df_cleaned['Weather']=='Clear']
clear.describe()
# Out:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   425.000000   425.000000            425.000000              425.000000
# mean    512.329412     9.738094             17.270588                4.489412
# std     284.236049     5.602884              7.277823                2.912320
# min       1.000000     0.590000              5.000000                0.000000
# 25%     275.000000     4.920000             11.000000                2.000000
# 50%     515.000000    10.090000             17.000000                5.000000
# 75%     750.000000    14.230000             24.000000                7.000000
# max    1000.000000    19.940000             29.000000                9.000000
#
#        Delivery_Time_min
# count         425.000000
# mean           52.668235
# std            20.819996
# min             8.000000
# 25%            37.000000
# 50%            51.000000
# 75%            67.000000
# max           141.000000

# %% [markdown]
# (['Windy', 'Clear', 'Foggy', 'Rainy', 'Snowy']

# %%
Windy=df_cleaned[df_cleaned['Weather']=='Windy']
Windy.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   86.000000    86.000000             86.000000               86.000000
# mean   476.000000    10.057674             15.790698                5.069767
# std    296.848109     5.596836              7.388570                2.655918
# min     12.000000     0.820000              5.000000                0.000000
# 25%    201.000000     5.312500              9.000000                3.250000
# 50%    460.500000    10.265000             15.000000                5.000000
# 75%    718.250000    14.052500             22.000000                7.000000
# max    997.000000    19.410000             29.000000                9.000000
#
#        Delivery_Time_min
# count          86.000000
# mean           55.081395
# std            21.636144
# min            16.000000
# 25%            39.250000
# 50%            54.500000
# 75%            71.000000
# max           122.000000

# %%
Foggy=df_cleaned[df_cleaned['Weather']=='Foggy']
Foggy.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   98.000000    98.000000             98.000000               98.000000
# mean   474.948980     9.773367             16.459184                4.142857
# std    290.105184     5.651775              7.509675                2.780640
# min      8.000000     0.710000              5.000000                0.000000
# 25%    204.750000     5.347500              9.250000                2.000000
# 50%    471.000000     9.145000             15.000000                4.000000
# 75%    718.250000    15.172500             24.000000                6.000000
# max    982.000000    19.730000             29.000000                9.000000
#
#        Delivery_Time_min
# count          98.000000
# mean           59.663265
# std            20.314001
# min            25.000000
# 25%            44.500000
# 50%            59.000000
# 75%            71.000000
# max           116.000000

# %%
Rainy=df_cleaned[df_cleaned['Weather']=='Rainy']
Rainy.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  188.000000   188.000000            188.000000              188.000000
# mean   518.196809    10.396543             17.005319                4.989362
# std    280.608275     5.757160              7.229246                3.036303
# min      2.000000     0.710000              5.000000                0.000000
# 25%    282.500000     5.000000             10.000000                2.000000
# 50%    531.000000    10.420000             17.000000                6.000000
# 75%    764.250000    15.390000             23.000000                8.000000
# max    996.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count         188.000000
# mean           59.095745
# std            22.302284
# min            15.000000
# 25%            42.000000
# 50%            57.000000
# 75%            72.000000
# max           126.000000

# %%
Snowy=df_cleaned[df_cleaned['Weather']=='Snowy']
Snowy.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   86.000000    86.000000             86.000000               86.000000
# mean   535.104651    11.157674             17.674419                4.755814
# std    310.587528     6.034314              6.795226                3.044517
# min      4.000000     0.680000              5.000000                0.000000
# 25%    253.750000     5.415000             13.000000                3.000000
# 50%    557.000000    12.280000             17.500000                5.000000
# 75%    827.750000    16.375000             22.750000                8.000000
# max    991.000000    19.930000             29.000000                9.000000
#
#        Delivery_Time_min
# count          86.000000
# mean           66.813953
# std            20.545222
# min            24.000000
# 25%            52.000000
# 50%            66.000000
# 75%            80.750000
# max           115.000000

# %%
Low=df_cleaned[df_cleaned['Traffic_Level']=='Low']
Low.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  347.000000   347.000000            347.000000              347.000000
# mean   511.948127    10.169568             17.288184                4.582133
# std    284.083015     5.725932              7.421882                2.959461
# min      1.000000     0.590000              5.000000                0.000000
# 25%    284.500000     5.325000             11.000000                2.000000
# 50%    526.000000    10.300000             17.000000                5.000000
# 75%    750.500000    15.310000             24.500000                7.000000
# max    999.000000    19.940000             29.000000                9.000000
#
#        Delivery_Time_min
# count         347.000000
# mean           52.498559
# std            20.809121
# min             8.000000
# 25%            36.000000
# 50%            51.000000
# 75%            68.000000
# max           141.000000

# %%
Medium=df_cleaned[df_cleaned['Traffic_Level']=='Medium']
Medium.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  355.000000   355.000000            355.000000              355.000000
# mean   496.067606     9.776535             16.878873                4.557746
# std    288.796765     5.579210              7.216544                2.931210
# min      6.000000     0.720000              5.000000                0.000000
# 25%    259.000000     4.460000             10.000000                2.000000
# 50%    495.000000    10.090000             17.000000                5.000000
# 75%    746.500000    14.445000             23.000000                7.000000
# max    993.000000    19.810000             29.000000                9.000000
#
#        Delivery_Time_min
# count         355.000000
# mean           56.250704
# std            21.223367
# min            13.000000
# 25%            42.000000
# 50%            54.000000
# 75%            71.000000
# max           123.000000

# %%
High=df_cleaned[df_cleaned['Traffic_Level']=='High']
High.describe()
# Out:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   181.000000   181.000000            181.000000              181.000000
# mean    524.370166    10.364862             16.779006                4.911602
# std     294.070912     5.835150              7.052643                2.830965
# min      13.000000     0.640000              5.000000                0.000000
# 25%     252.000000     5.530000             11.000000                3.000000
# 50%     525.000000    10.890000             17.000000                5.000000
# 75%     787.000000    15.350000             23.000000                7.000000
# max    1000.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count         181.000000
# mean           64.298343
# std            21.659985
# min            21.000000
# 25%            48.000000
# 50%            63.000000
# 75%            77.000000
# max           122.000000

# %%
morning=df_cleaned[df_cleaned['Time_of_Day']=='Morning']
morning.describe()
# Out:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   281.000000   281.000000            281.000000              281.000000
# mean    502.370107    10.320427             16.725979                4.469751
# std     288.113615     5.833687              7.326054                2.823367
# min       8.000000     0.710000              5.000000                0.000000
# 25%     252.000000     4.830000             10.000000                2.000000
# 50%     517.000000    10.750000             16.000000                5.000000
# 75%     744.000000    15.170000             23.000000                7.000000
# max    1000.000000    19.750000             29.000000                9.000000
#
#        Delivery_Time_min
# count         281.000000
# mean           56.405694
# std            21.714030
# min             8.000000
# 25%            41.000000
# 50%            56.000000
# 75%            70.000000
# max           126.000000

# %%
afternoon=df_cleaned[df_cleaned['Time_of_Day']=='Afternoon']
afternoon.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  257.000000   257.000000            257.000000              257.000000
# mean   532.202335    10.053035             16.871595                4.723735
# std    290.982143     5.685740              7.203722                2.927099
# min     11.000000     0.590000              5.000000                0.000000
# 25%    278.000000     5.300000             11.000000                2.000000
# 50%    565.000000    10.420000             17.000000                5.000000
# 75%    788.000000    14.520000             23.000000                7.000000
# max    999.000000    19.940000             29.000000                9.000000
#
#        Delivery_Time_min
# count         257.000000
# mean           56.108949
# std            21.239975
# min            16.000000
# 25%            38.000000
# 50%            56.000000
# 75%            71.000000
# max           109.000000

# %%
evening=df_cleaned[df_cleaned['Time_of_Day']=='Evening']
evening.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  269.000000   269.000000            269.000000              269.000000
# mean   482.799257     9.998587             17.375465                4.724907
# std    280.808024     5.527422              7.205170                2.989811
# min      1.000000     0.680000              5.000000                0.000000
# 25%    260.000000     5.380000             11.000000                2.000000
# 50%    463.000000     9.950000             17.000000                5.000000
# 75%    714.000000    14.700000             24.000000                8.000000
# max    993.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count         269.000000
# mean           57.509294
# std            22.162327
# min            13.000000
# 25%            42.000000
# 50%            56.000000
# 75%            71.000000
# max           141.000000

# %%
night=df_cleaned[df_cleaned['Time_of_Day']=='Night']
night.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   76.000000    76.000000             76.000000               76.000000
# mean   537.447368     9.240263             17.342105                4.684211
# std    298.249399     5.747524              7.477170                3.051603
# min      7.000000     0.640000              5.000000                0.000000
# 25%    349.000000     3.817500             10.750000                2.000000
# 50%    550.500000     9.155000             17.500000                5.000000
# 75%    793.000000    13.527500             24.000000                7.250000
# max    986.000000    18.970000             29.000000                9.000000
#
#        Delivery_Time_min
# count          76.000000
# mean           53.736842
# std            20.090043
# min            23.000000
# 25%            39.000000
# 50%            49.000000
# 75%            67.250000
# max           108.000000

# %%
scooter=df_cleaned[df_cleaned['Vehicle_Type']=="Scooter"]
scooter.describe()
# Out:
#           Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count   260.000000   260.000000            260.000000              260.000000
# mean    485.480769     9.962423             17.100000                4.646154
# std     287.136568     5.424133              7.418905                2.910138
# min       1.000000     0.610000              5.000000                0.000000
# 25%     236.500000     5.342500             10.000000                2.000000
# 50%     489.500000    10.285000             17.000000                5.000000
# 75%     703.250000    14.140000             24.000000                7.000000
# max    1000.000000    19.740000             29.000000                9.000000
#
#        Delivery_Time_min
# count         260.000000
# mean           55.226923
# std            20.611839
# min            13.000000
# 25%            39.000000
# 50%            52.000000
# 75%            70.000000
# max           123.000000

# %%
bike=df_cleaned[df_cleaned['Vehicle_Type']=="Bike"]
bike.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  451.000000   451.000000            451.000000              451.000000
# mean   510.000000    10.018381             16.946785                4.667406
# std    287.949672     5.840618              7.214295                2.956767
# min      4.000000     0.590000              5.000000                0.000000
# 25%    262.000000     4.355000             11.000000                2.000000
# 50%    505.000000    10.200000             17.000000                5.000000
# 75%    774.000000    15.130000             23.000000                7.000000
# max    998.000000    19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count         451.000000
# mean           56.618625
# std            21.833532
# min             8.000000
# 25%            40.000000
# 50%            56.000000
# 75%            71.000000
# max           122.000000

# %%
car=df_cleaned[df_cleaned['Vehicle_Type']=="Car"]
car.describe()
# Out:
#          Order_ID  Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  172.000000   172.000000            172.000000              172.000000
# mean   537.360465    10.273430             17.087209                4.558140
# std    287.874279     5.701953              7.177650                2.863787
# min      2.000000     0.710000              5.000000                0.000000
# 25%    308.000000     5.515000             11.000000                2.000000
# 50%    574.500000    10.310000             17.000000                4.000000
# 75%    778.750000    15.260000             23.000000                7.000000
# max    999.000000    19.810000             29.000000                9.000000
#
#        Delivery_Time_min
# count         172.000000
# mean           57.732558
# std            22.304341
# min            17.000000
# 25%            42.000000
# 50%            56.000000
# 75%            71.000000
# max           141.000000

# %%
categorical_columns
# Out:
# Index(['Weather', 'Traffic_Level', 'Time_of_Day', 'Vehicle_Type'], dtype='object')

# %%
df_cleaned['Weather'].unique()
# Out:
# array(['Windy', 'Clear', 'Foggy', 'Rainy', 'Snowy'], dtype=object)

# %%
weather_map={'Windy':1,'Clear':2,'Foggy':3,'Rainy':4,'Snowy':5}

# %%
df_cleaned['Traffic_Level'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
traffic_map={'Low':1,'Medium':2,'High':3}

# %%
df_cleaned['Time_of_Day'].unique()
# Out:
# array(['Afternoon', 'Evening', 'Night', 'Morning'], dtype=object)

# %%
time_of_day_map={'Morning':1,'Afternoon':2,'Evening':3,'Night':4}

# %%
df_cleaned['Vehicle_Type'].unique()
# Out:
# array(['Scooter', 'Bike', 'Car'], dtype=object)

# %%
vehicle_map={'Scooter':1,'Bike':2,'Car':3}

# %%
df_cleaned.loc[:,'Weather']=df_cleaned['Weather'].map(weather_map)
df_cleaned.loc[:,'Traffic_Level']=df_cleaned['Traffic_Level'].map(traffic_map)
df_cleaned.loc[:,'Time_of_Day']=df_cleaned['Time_of_Day'].map(time_of_day_map)
df_cleaned.loc[:,'Vehicle_Type']=df_cleaned['Vehicle_Type'].map(vehicle_map)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
x=df_cleaned.drop(columns=['Delivery_Time_min'],axis=1)
Y=df_cleaned[['Delivery_Time_min']]

# %%
x
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         522         7.93       1             1           2            1
# 1         738        16.42       2             2           3            2
# 2         741         9.52       3             1           4            1
# 3         661         7.44       4             2           2            1
# 4         412        19.03       2             1           1            2
# ..        ...          ...     ...           ...         ...          ...
# 995       107         8.50       2             3           3            3
# 996       271        16.28       4             1           1            1
# 997       861        15.62       5             3           3            1
# 998       436        14.17       2             1           2            2
# 999       103         6.63       3             1           4            1
#
#      Preparation_Time_min  Courier_Experience_yrs
# ...

# %%
Y
# Out:
#      Delivery_Time_min
# 0                   43
# 1                   84
# 2                   59
# 3                   37
# 4                   68
# ..                 ...
# 995                 54
# 996                 71
# 997                 81
# 998                 55
# 999                 58
#
# [883 rows x 1 columns]

# %%
x = x.drop(['Order_ID'],axis=1)

# %%
x
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0           7.93       1             1           2            1
# 1          16.42       2             2           3            2
# 2           9.52       3             1           4            1
# 3           7.44       4             2           2            1
# 4          19.03       2             1           1            2
# ..           ...     ...           ...         ...          ...
# 995         8.50       2             3           3            3
# 996        16.28       4             1           1            1
# 997        15.62       5             3           3            1
# 998        14.17       2             1           2            2
# 999         6.63       3             1           4            1
#
#      Preparation_Time_min  Courier_Experience_yrs
# 0                      12                     1.0
# 1                      20                     2.0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,Y_train,Y_test=train_test_split(x,Y,test_size=0.30,random_state=21)

# %%
regression=LinearRegression()
regression.fit(x_train,Y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    r2_square = r2_score(true, predicted)
    return mae, r2_square,mse

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
}

for i in range (len(list((models)))):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
list(models.values())[2]
# Out:
# Ridge()

# %%
list(models.keys())[0]
# Out:
# 'LinearRegression'

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(x_train,Y_train)

    #Make Predictions
    y_pred=model.predict(x_test)

    mae, r2_square,mse=evaluate_model(Y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    

    print('Model Training Performance')
   
    print("MAE:",mae)
    print("R2 score",r2_square)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# MAE: 6.418184415250036
# R2 score 0.7911408718409603
# ...
#
#
# Lasso
# Model Training Performance
# MAE: 6.6328979755928605
# R2 score 0.7857624296985595
# ...
#
#
# Ridge
# Model Training Performance
# MAE: 6.418193591442106
# R2 score 0.7911540297149845
# ...
#
#
# Elasticnet
# Model Training Performance
# MAE: 6.9381476420573405
# R2 score 0.7773475089344788
# ...

# %%
linear_regression=LinearRegression()
linear_regression.fit(x_train,Y_train)
# Out:
# LinearRegression()

# %%
import pickle

model_pkl_file="modellinear.pkl"

with open(model_pkl_file,'wb') as file:
    pickle.dump(linear_regression,file)

# %%
with open(model_pkl_file, 'rb') as file:  
    model = pickle.load(file)

# %%
x_train
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 442        13.44       2             1           4            2
# 954         5.41       2             3           1            1
# 130         1.30       3             1           3            2
# 696         1.27       3             3           2            2
# 180         9.54       4             2           3            1
# ..           ...     ...           ...         ...          ...
# 416         3.83       4             1           3            3
# 52         19.81       5             2           2            3
# 871         0.64       2             3           4            2
# 931        12.51       2             2           3            2
# 232        14.07       2             3           2            2
#
#      Preparation_Time_min  Courier_Experience_yrs
# 442                    29                     0.0
# 954                    17                     6.0
# ...

# %%
df_cleaned.drop('Order_ID', axis=1, inplace=True)
# Out:
# C:\Users\Harishwar\AppData\Local\Temp\ipykernel_24380\203412561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop('Order_ID', axis=1, inplace=True)

# %%
df_cleaned
# Out:
#      Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0           7.93       1             1           2            1
# 1          16.42       2             2           3            2
# 2           9.52       3             1           4            1
# 3           7.44       4             2           2            1
# 4          19.03       2             1           1            2
# ..           ...     ...           ...         ...          ...
# 995         8.50       2             3           3            3
# 996        16.28       4             1           1            1
# 997        15.62       5             3           3            1
# 998        14.17       2             1           2            2
# 999         6.63       3             1           4            1
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                      12                     1.0                 43
# ...

# %%
y_pred=model.predict(pd.DataFrame([[10,3,2,4,2,15,5.0]]))
# Out:
# c:\Users\Harishwar\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([[56.74284298]])
